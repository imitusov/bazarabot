# %%
from t_tech.invest import Client
import os


TOKEN = os.getenv('TINVEST_TOKEN')
print(TOKEN)

with Client(TOKEN) as client:
    print(client.users.get_accounts())
# Out:
# t.nReudFUkeW-qEhkFjGgY2H0HpVOuAysdfStFmMCnnBopfTj3MW-HYpA23iFDyQFVq7TgwTG8K_fYjLkf-60R6Q                   # FULL-ACCESS token. Equivalent to a password for the account.
# /var/folders/7y/4ttlsb6s1n56rs7bqkjqvc9r0000gn/T/ipykernel_56623/1615739155.py:9: DeprecatedWarning: get_accounts is deprecated as of 1.0.0.
#   print(client.users.get_accounts())
# I0821 22:31:21.390841 6061483 ssl_transport_security.cc:2399] Handshake failed with error SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED: self signed certificate in certificate chain
# None GetAccounts UNAVAILABLE failed to connect to all addresses; last error: UNKNOWN: ipv4:178.130.128.33:443: Tls handshake failed (TSI_PROTOCOL_FAILURE): SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED: self signed certificate in certificate chain: OK
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/Documents/projects/zarabot/.venv/lib/python3.12/site-packages/t_tech/invest/_errors.py:24, in handle_request_error.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      23 try:
# ---> 24     return func(*args, **kwargs)
#      25 except RpcError as e:
#
# File ~/Documents/projects/zarabot/.venv/lib/python3.12/site-packages/t_tech/invest/services.py:1824, in UsersService.get_accounts(self)
#    1823 request = GetAccountsRequest()
# -> 1824 response, call = self.stub.GetAccounts.with_call(
#    1825     request=_grpc_helpers.dataclass_to_protobuf(
#    1826         request, users_pb2.GetAccountsRequest()
#    1827     ),
#    1828     metadata=self.metadata,
#    1829 )
#    1830 log_request(get_tracking_id_from_call(call), "GetAccounts")
#
# File ~/Documents/projects/zarabot/.venv/lib/python3.12/site-packages/grpc/_channel.py:1182, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1179 state, call = self._blocking(
#    1180     request, timeout, metadata, credentials, wait_for_ready, compression
#    1181 )
# -> 1182 return _end_unary_response_blocking(state, call, True, None)
#
# File ~/Documents/projects/zarabot/.venv/lib/python3.12/site-packages/grpc/_channel.py:999, in _end_unary_response_blocking(state, call, with_call, deadline)
#     998     return state.response
# --> 999 raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNKNOWN: ipv4:178.130.128.33:443: Tls handshake failed (TSI_PROTOCOL_FAILURE): SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED: self signed certificate in certificate chain: OK"
# 	debug_error_string = "UNAVAILABLE:failed to connect to all addresses; last error: UNKNOWN: ipv4:178.130.128.33:443: Tls handshake failed (TSI_PROTOCOL_FAILURE): SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED: self signed certificate in certificate chain: OK"
# >
#
# The above exception was the direct cause of the following exception:
#
# RequestError                              Traceback (most recent call last)
# Cell In[5], line 9
#       5 TOKEN = os.getenv('TINVEST_TOKEN')
#       6 print(TOKEN)
#       7
#       8 with Client(TOKEN) as client:
# ----> 9     print(client.users.get_accounts())
#
# File ~/Documents/projects/zarabot/.venv/lib/python3.12/site-packages/deprecation.py:260, in deprecated.<locals>._function_wrapper.<locals>._inner(*args, **kwargs)
#     255     the_warning = cls(function.__name__, deprecated_in,
#     256                       removed_in, details)
#     257     warnings.warn(the_warning, category=DeprecationWarning,
#     258                   stacklevel=2)
# --> 260 return function(*args, **kwargs)
#
# File ~/Documents/projects/zarabot/.venv/lib/python3.12/site-packages/t_tech/invest/_errors.py:42, in handle_request_error.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      37     if status_code == StatusCode.UNAUTHENTICATED:
#      38         raise UnauthenticatedError(
#      39             status_code, details, metadata
#      40         ) from e
# ---> 42     raise RequestError(status_code, details, metadata) from e
#      43 raise
#
# RequestError: (<StatusCode.UNAVAILABLE: (<StatusCode.unavailable: 14>, 'unavailable')>, 'failed to connect to all addresses; last error: UNKNOWN: ipv4:178.130.128.33:443: Tls handshake failed (TSI_PROTOCOL_FAILURE): SSL_ERROR_SSL: error:1000007d:SSL routines:OPENSSL_internal:CERTIFICATE_VERIFY_FAILED: self signed certificate in certificate chain: OK', None)
